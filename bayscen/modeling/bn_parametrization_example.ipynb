# %% [markdown]
# # BayScen — Bayesian Network Parameterization
#
# This notebook demonstrates the complete BN training pipeline for all three BayScen scenarios.
#
# ## Pipeline Overview
#
# 1. Load real-world meteorological data (43,000+ Frost API observations)
# 2. Parse the learned Bi-CaMML structure
# 3. Fit base environmental CPDs (Bayesian estimation, BDeu prior, ESS=5)
# 4. Extend with ISO 34503:2023-grounded capability variables as leaf nodes
#    - Uniform-weight aggregation: P(A=a* | parents) concentrates mass on the nearest K=6 level
# 5. Add scenario-specific trajectory variables:
#    - S1/S2 (junction): Start/Goal positions + Conflict_Geometry
#    - S3 (cut-in):       Cut_In_Direction (binary concrete variable)
# 6. Save all intermediate and final models
#
# ## Scenarios
#
# | ID | Description | Env vars | Trajectory variable |
# |----|-------------|----------|--------------------|
# | S1 | Vehicle–Vehicle Junction | 8 | Conflict_Geometry (g1/g2/g3) |
# | S2 | Vehicle–Cyclist Junction | 9 (+Sun_Altitude_Angle) | Conflict_Geometry |
# | S3 | Vehicle–Vehicle Cut-In   | 9 (+Sun_Altitude_Angle) | Cut_In_Direction (Left/Right) |

# %% [markdown]
# ## Setup and Imports

# %%
import sys
from pathlib import Path
from collections import defaultdict

# Add bayscen to path
sys.path.append(str(Path.cwd().parent))

from modeling.bn_parametrization import BayesianNetworkParametrizer
from modeling.bn_utils import load_model, print_cpd_as_dataframe
from abstraction.abstract_variables import (
    CAPABILITY_VARIABLES,
    SENSOR_PERCEPTION, SURFACE_TRACTION, LATERAL_STABILITY, CONFLICT_GEOMETRY,
)

import warnings
warnings.filterwarnings('ignore')

print("Imports OK")

# %% [markdown]
# ## Verify Capability Variable Definitions
#
# Confirm the ISO 34503:2023-grounded capability variables and their uniform weights.

# %%
print("ISO 34503:2023-Grounded Capability Variables")
print("=" * 70)

for var in [SENSOR_PERCEPTION, SURFACE_TRACTION, LATERAL_STABILITY]:
    print(f"\n{var.name}  [{var.iso_clause}]")
    print(f"  States : {var.values}")
    print(f"  Parents (uniform weights):")
    for parent, rel, w in var.parents:
        print(f"    {parent:28s}  {rel:8s}  weight={w:.4f}")

print(f"\n{CONFLICT_GEOMETRY.name}  [{CONFLICT_GEOMETRY.iso_clause}]")
print(f"  States : {CONFLICT_GEOMETRY.values}  (g1/g2/g3 conflict points)")
print(f"  Deterministic mapping from (Start_Ego, Goal_Ego, Start_Other, Goal_Other)")

# %%
# Verify that Sensor_Perception adapts to Scenario 2/3 (adds Sun_Altitude_Angle)
s1_vars = ['Cloudiness','Wind_Intensity','Precipitation','Precipitation_Deposits',
           'Wetness','Fog_Density','Road_Friction','Fog_Distance']
s2_vars = ['Sun_Altitude_Angle'] + s1_vars

s1_parents = SENSOR_PERCEPTION.get_parents_for_scenario(s1_vars)
s2_parents = SENSOR_PERCEPTION.get_parents_for_scenario(s2_vars)

print("Sensor_Perception parent counts:")
print(f"  S1 (no Sun_Altitude_Angle): {len(s1_parents)} parents, weight per parent = {s1_parents[0][2]:.2f}")
print(f"  S2/S3 (+ Sun_Altitude_Angle): {len(s2_parents)} parents, weight per parent = {s2_parents[0][2]:.2f}")

# %% [markdown]
# ## Define Paths

# %%
DATA_PATH = "../../data/processed/bayscen_final_data.csv"

STRUCT = {
    1: "structure_learning/learned_structures/scenario1_structure.txt",
    2: "structure_learning/learned_structures/scenario2_structure.txt",
    3: "structure_learning/learned_structures/scenario3_structure.txt",
}

print(f"Data  : {DATA_PATH}")
for n, p in STRUCT.items():
    print(f"S{n} BN : {p}")

# %% [markdown]
# ## Scenario 1: Vehicle–Vehicle Junction
#
# 8 environmental variables, Conflict_Geometry with states g1/g2/g3.

# %%
param_s1 = BayesianNetworkParametrizer(
    data_path=DATA_PATH,
    structure_path=STRUCT[1],
    scenario=1,
)
param_s1.run_full_pipeline()

# %% [markdown]
# ## Scenario 2: Vehicle–Cyclist Junction
#
# 9 environmental variables (adds Sun_Altitude_Angle, ISO §10.4(d)).
# Sensor_Perception now has 5 parents with equal weight 0.20.

# %%
param_s2 = BayesianNetworkParametrizer(
    data_path=DATA_PATH,
    structure_path=STRUCT[2],
    scenario=2,
)
param_s2.run_full_pipeline()

# %% [markdown]
# ## Scenario 3: Vehicle–Vehicle Cut-In
#
# 9 environmental variables (same as S2). Cut_In_Direction (Left/Right) is retained as
# a concrete variable — the binary direction is already fully expressive and requires
# no further abstraction (Paper Section II-C-5).

# %%
param_s3 = BayesianNetworkParametrizer(
    data_path=DATA_PATH,
    structure_path=STRUCT[3],
    scenario=3,
)
param_s3.run_full_pipeline()

# %% [markdown]
# ## Alternative: Step-by-Step Execution
#
# For closer inspection, run each pipeline stage individually.

# %%
# Create a fresh parametrizer for S1
param = BayesianNetworkParametrizer(
    data_path=DATA_PATH,
    structure_path=STRUCT[1],
    scenario=1,
)

# Step 1: Load data
param.load_data()
print(f"\nData shape: {param.data.shape}")
print(param.data.head())

# %%
# Step 2: Load structure
param.load_structure()
print(f"\n{len(param.edges)} edges loaded")

# %%
# Inspect the capability structure that will be used
print("Capability structure (built from abstract_variables.py):")
print("=" * 70)
for cap, parents in param.capability_structure.items():
    total_w = sum(w for _, _, w in parents)
    print(f"\n{cap}:")
    for parent, rel, w in parents:
        print(f"  <- {parent:28s}  {rel:8s}  weight={w:.4f} ({w/total_w*100:.1f}%)")
print("\nNote: weights are uniform (1/n_parents) per new paper Section II-C-4")

# %%
# Step 3: Fit base model
param.fit_base_model()

# %%
# Step 4: Extend with capability variables
param.extend_with_capabilities()

# %%
# Step 5a: Add junction variables (S1/S2)
param.add_junction_variables()

# %%
# Step 6: Save models
param.save_models()

# %% [markdown]
# ## Inspect the Trained Model

# %%
# Load the final S1 model
full_model = load_model('models/scenario1_full_bayesian_network.pkl')

print(f"Model nodes ({len(full_model.nodes())}):")
print(sorted(full_model.nodes()))

print(f"\nModel valid: {full_model.check_model()}")

# %%
# Inspect Sensor_Perception CPD — should be hard (1-hot) columns
# because we use uniform-weight aggregation with nearest-level assignment
import numpy as np

sp_cpd = full_model.get_cpds('Sensor_Perception')
col_matrix = sp_cpd.values.reshape(6, -1)  # 6 states × n_parent_combinations

# Each column should sum to 1 and have exactly one non-zero entry
print("Sensor_Perception CPD properties:")
print(f"  Shape: {col_matrix.shape}")
print(f"  All columns sum to 1: {np.allclose(col_matrix.sum(axis=0), 1.0)}")
nonzero_per_col = (col_matrix > 0).sum(axis=0)
print(f"  All columns have exactly 1 non-zero entry: {(nonzero_per_col == 1).all()}")
print("  (Hard assignment — uniform-weight aggregation → nearest K=6 level)")

# %%
# Inspect Conflict_Geometry CPD — deterministic mapping
cg_cpd = full_model.get_cpds('Conflict_Geometry')

print("Conflict_Geometry CPD (sample of 20 rows):")
df = print_cpd_as_dataframe(cg_cpd, max_rows=20)
print(df)

# %% [markdown]
# ## Compare All Three Scenarios

# %%
scenarios = {
    1: load_model('models/scenario1_full_bayesian_network.pkl'),
    2: load_model('models/scenario2_full_bayesian_network.pkl'),
    3: load_model('models/scenario3_full_bayesian_network.pkl'),
}

desc = {1: 'Vehicle–Vehicle junction', 2: 'Vehicle–Cyclist junction', 3: 'Cut-In'}

print("Scenario Comparison")
print("=" * 70)
for n, m in scenarios.items():
    nodes = sorted(m.nodes())
    print(f"\nS{n} ({desc[n]}):")
    print(f"  Nodes : {len(nodes)}  Edges: {len(m.edges())}")
    print(f"  Nodes : {nodes}")

# Extra nodes in S2/S3 vs S1
extra_s2 = set(scenarios[2].nodes()) - set(scenarios[1].nodes())
extra_s3 = set(scenarios[3].nodes()) - set(scenarios[1].nodes())
print(f"\nExtra in S2 vs S1: {extra_s2}")
print(f"Extra in S3 vs S1: {extra_s3}")

# %%
# Count variable categories per scenario
env_s1 = ['Cloudiness','Wind_Intensity','Precipitation','Precipitation_Deposits',
          'Wetness','Fog_Density','Road_Friction','Fog_Distance']
env_s2s3 = ['Sun_Altitude_Angle'] + env_s1
cap_vars  = ['Sensor_Perception','Surface_Traction','Lateral_Stability']

print(f"{'Scenario':<10} {'Env vars':<12} {'Cap vars':<12} {'Traj vars':<20} {'Total':<8}")
print("-" * 65)
for n, env, traj in [
    (1, env_s1,   "Conflict_Geometry + 4 positions"),
    (2, env_s2s3, "Conflict_Geometry + 4 positions"),
    (3, env_s2s3, "Cut_In_Direction"),
]:
    traj_count = 5 if n in [1,2] else 1  # 4 positions + Conflict_Geometry, or just Cut_In
    total = len(env) + len(cap_vars) + traj_count
    print(f"S{n:<9} {len(env):<12} {len(cap_vars):<12} {traj:<20} {total:<8}")

# %% [markdown]
# ## Command Line Usage
#
# ```bash
# # Scenario 1 — Vehicle–Vehicle junction
# python bn_parametrization.py --scenario 1
#
# # Scenario 2 — Vehicle–Cyclist junction (adds Sun_Altitude_Angle)
# python bn_parametrization.py --scenario 2
#
# # Scenario 3 — Vehicle–Vehicle cut-in
# python bn_parametrization.py --scenario 3
# ```
#
# Output models are written to `modeling/models/scenario{N}_full_bayesian_network.pkl`.

# %% [markdown]
# ## Next Steps
#
# Trained models are now ready for scenario generation:
#
# ```bash
# cd ../generation
#
# # BayScen (rarity-prioritized)
# python generate_scenarios.py --scenario 1 --mode rare   # 648 configs
# python generate_scenarios.py --scenario 2 --mode rare   # 648 configs
# python generate_scenarios.py --scenario 3 --mode rare   # 216 configs
#
# # BayScen-Common ablation
# python generate_scenarios.py --scenario 1 --mode common
# ```
#
# See `generation/scenario_generation_tutorial.ipynb` for the interactive generation walkthrough.
